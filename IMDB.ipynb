# %%
from IPython.display import display, HTML

html_text = """
<h2 style='color:#2c3e50;'>About Project: IMDB Movie Analysis</h2>

<p style='font-size:15px; line-height:1.6;'>
<b>Objective:</b><br>
As a data analyst intern at <b>IMDB</b>, your task is to explore and analyze the IMDB Movies dataset.
Your goal is to answer specific business questions, uncover insights into movie trends, and provide 
actionable recommendations. Using Python libraries such as <b>Pandas</b>, <b>NumPy</b>, 
<b>Seaborn</b>, and <b>Matplotlib</b>, you will investigate genre popularity, rating patterns, 
and key factors that influence movie success.
</p>
"""

display(HTML(html_text))

from IPython.display import Markdown, display

display(Markdown("""
# **About Company: IMDB (Internet Movie Database)**

The **Internet Movie Database (IMDB)** is the world’s largest and most authoritative online 
database for movies, TV shows, actors, directors, production crews, and entertainment industry 
data. Founded in 1990, IMDB provides comprehensive information including cast details, release 
dates, ratings, reviews, trivia, box-office performance, and more.

It is widely used by film enthusiasts, researchers, production studios, and industry professionals 
to explore cinematic content and analyze global entertainment trends. IMDB’s user-generated ratings 
and reviews also make it a powerful platform for understanding audience preferences and the factors 
that drive movie popularity and success.
"""))


from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>Tools and Libraries Used</h2>

<p style='font-size:15px; line-height:1.6;'>
This project utilizes a set of essential Python libraries that support data analysis, numerical 
processing, and high-quality visualizations:
</p>

<ul style='font-size:15px; line-height:1.6;'>
    <li><b>Python</b></li>
    <li><b>Pandas</b>: Data manipulation and analysis</li>
    <li><b>NumPy</b>: Numerical computations</li>
    <li><b>Matplotlib</b>: Data visualization</li>
    <li><b>Seaborn</b>: Advanced visualization</li>
</ul>
"""))


from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>Dataset Overview</h2>

<p style='font-size:15px; line-height:1.7; text-align:justify;'>
The dataset contains comprehensive information about movies, including titles, release timelines, 
ratings, genres, summaries, financial data, and production details. A brief description of each 
column is provided below:
</p>

<ul style='font-size:15px; line-height:1.6;'>
    <li><b>names</b>: Movie titles</li>
    <li><b>date_x</b>: Release dates</li>
    <li><b>score</b>: IMDB ratings</li>
    <li><b>genre</b>: Genres</li>
    <li><b>overview</b>: Movie summaries</li>
    <li><b>crew</b>: Cast and crew information</li>
    <li><b>orig_title</b>: Original titles</li>
    <li><b>status</b>: Release status (e.g., released, post-production)</li>
    <li><b>orig_lang</b>: Original language</li>
    <li><b>budget_x</b>: Production budgets</li>
    <li><b>revenue</b>: Box office revenues</li>
    <li><b>country</b>: Production country</li>
</ul>
"""))



from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>Loading the Dataset and Performing Initial Setup</h2>

<p style='font-size:15px; line-height:1.7; text-align:justify;'>
<b>Task:</b> Load the dataset and perform the initial setup required for the project.
This includes preparing the environment, importing necessary libraries, and loading the dataset 
into the workspace. Initial setup also involves inspecting the dataset, checking for missing values, 
and ensuring it is ready for detailed analysis.
</p>

<h3 style='color:#2c3e50;'>1. Project Setup and Data Loading</h3>

<p style='font-size:15px; line-height:1.7; text-align:justify;'>
During this step, you will import essential libraries, load the dataset, perform basic checks, 
and confirm that the data has been properly loaded for further processing.
</p>
"""))
# Out:
# <h2 style='color:#2c3e50;'>About Project: IMDB Movie Analysis</h2>
#
# <p style='font-size:15px; line-height:1.6;'>
# <b>Objective:</b><br>
# As a data analyst intern at <b>IMDB</b>, your task is to explore and analyze the IMDB Movies dataset.
# Your goal is to answer specific business questions, uncover insights into movie trends, and provide
# actionable recommendations. Using Python libraries such as <b>Pandas</b>, <b>NumPy</b>,
# <b>Seaborn</b>, and <b>Matplotlib</b>, you will investigate genre popularity, rating patterns,
# and key factors that influence movie success.
# </p>
# # **About Company: IMDB (Internet Movie Database)**
#
# The **Internet Movie Database (IMDB)** is the world’s largest and most authoritative online
# database for movies, TV shows, actors, directors, production crews, and entertainment industry
# data. Founded in 1990, IMDB provides comprehensive information including cast details, release
# ...

# %%
from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>Project Questions</h2>

<h3 style='color:#2c3e50;'>1. What libraries are required for this project, and why are they useful in data analysis?</h3>
<p style='font-size:15px; line-height:1.7; text-align:justify;'>
This project relies on essential Python libraries that assist in data handling, visualization, 
statistical analysis, and numerical computation. These libraries make it easier to explore, 
clean, and analyze large datasets effectively.
</p>

<h3 style='color:#2c3e50;'>2. Load the dataset. What is the shape of the dataset? What does each row and column represent?</h3>
<p style='font-size:15px; line-height:1.7; text-align:justify;'>
Once the dataset is loaded, checking its shape reveals the total number of rows and columns. 
Each <b>row</b> corresponds to a movie record, while each <b>column</b> represents specific 
attributes such as titles, genres, release dates, ratings, budgets, revenues, and other 
descriptive metadata.
</p>
"""))
# Out:
# <h2 style='color:#2c3e50;'>Project Questions</h2>
#
# <h3 style='color:#2c3e50;'>1. What libraries are required for this project, and why are they useful in data analysis?</h3>
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# This project relies on essential Python libraries that assist in data handling, visualization,
# statistical analysis, and numerical computation. These libraries make it easier to explore,
# clean, and analyze large datasets effectively.
# </p>
#
# <h3 style='color:#2c3e50;'>2. Load the dataset. What is the shape of the dataset? What does each row and column represent?</h3>
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# Once the dataset is loaded, checking its shape reveals the total number of rows and columns.
# Each <b>row</b> corresponds to a movie record, while each <b>column</b> represents specific
# attributes such as titles, genres, release dates, ratings, budgets, revenues, and other
# descriptive metadata.
# ...

# %%
#Using Python and libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
 #Load the dataset 
df = pd.read_csv("imdb_movies.csv")
df
# Display the top 5 rows of datasets
df.head()
# Out:
#                          names       date_x  score  \
# 0                    Creed III  03/02/2023    73.0
# 1     Avatar: The Way of Water  12/15/2022    78.0
# 2  The Super Mario Bros. Movie  04/05/2023    76.0
# 3                      Mummies  01/05/2023    70.0
# 4                    Supercell  03/17/2023    61.0
#
#                                            genre  \
# 0                                  Drama, Action
# 1             Science Fiction, Adventure, Action
# 2  Animation, Adventure, Family, Fantasy, Comedy
# 3  Animation, Comedy, Family, Adventure, Fantasy
# 4                                         Action
#
#                                             overview  \
# 0  After dominating the boxing world, Adonis Cree...
# 1  Set more than a decade after the events of the...
# 2  While working underground to fix a water main,...
# 3  Through a series of unfortunate events, three ...
# 4  Good-hearted teenager William always lived in ...
#
# ...

# %%
 #What is the shape of the dataset
print("dataset shape:",df.shape)
df.info()
# Out:
# dataset shape: (10178, 12)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10178 entries, 0 to 10177
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   names       10178 non-null  object
#  1   date_x      10178 non-null  object
#  2   score       10178 non-null  float64
#  3   genre       10093 non-null  object
#  4   overview    10178 non-null  object
#  5   crew        10122 non-null  object
#  6   orig_title  10178 non-null  object
#  7   status      10178 non-null  object
#  8   orig_lang   10178 non-null  object
#  9   budget_x    10178 non-null  float64
#  10  revenue     10178 non-null  float64
#  11  country     10178 non-null  object
# dtypes: float64(3), object(9)
# memory usage: 954.3+ KB

# %%
from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>2. Data Overview and Basic Exploration</h2>

<p style='font-size:15px; line-height:1.7; text-align:justify;'>
<b>Task:</b> Explore the structure and composition of the dataset.  
This includes reviewing the dataset's dimensions, column names, data types, and identifying 
any missing or inconsistent values. This initial examination helps ensure that the data is 
ready for meaningful analysis.
</p>
"""))
# Out:
# <h2 style='color:#2c3e50;'>2. Data Overview and Basic Exploration</h2>
#
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# <b>Task:</b> Explore the structure and composition of the dataset.
# This includes reviewing the dataset's dimensions, column names, data types, and identifying
# any missing or inconsistent values. This initial examination helps ensure that the data is
# ready for meaningful analysis.
# </p>

# %%
from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'> Project Questions</h2>

<h3 style='color:#2c3e50;'>1. Use <code>.info()</code> to understand the data types and missing values. 
What potential issues can you spot?</h3>
<p style='font-size:15px; line-height:1.7; text-align:justify;'>
This step helps identify missing values, inappropriate data types, inconsistent formatting, and 
other issues that may require cleaning or preprocessing before performing deeper analysis.
</p>

<h3 style='color:#2c3e50;'>2. Describe the main characteristics of each column using <code>.describe()</code>. 
What can you infer from the mean, median, and distribution of numerical columns?</h3>
<p style='font-size:15px; line-height:1.7; text-align:justify;'>
This summary provides insights into the central tendency, spread, and shape of numerical data. 
It highlights patterns such as skewness, outliers, and possible deviations between mean and median, 
which are helpful for understanding the dataset's overall distribution.
</p>
"""))
# Out:
# <h2 style='color:#2c3e50;'> Project Questions</h2>
#
# <h3 style='color:#2c3e50;'>1. Use <code>.info()</code> to understand the data types and missing values.
# What potential issues can you spot?</h3>
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# This step helps identify missing values, inappropriate data types, inconsistent formatting, and
# other issues that may require cleaning or preprocessing before performing deeper analysis.
# </p>
#
# <h3 style='color:#2c3e50;'>2. Describe the main characteristics of each column using <code>.describe()</code>.
# What can you infer from the mean, median, and distribution of numerical columns?</h3>
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# This summary provides insights into the central tendency, spread, and shape of numerical data.
# It highlights patterns such as skewness, outliers, and possible deviations between mean and median,
# ...

# %%
 #Convert data type of date_x into datetime 
df["date_x"]= pd.to_datetime(df["date_x"])
 # Checking the datatyp
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10178 entries, 0 to 10177
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   names       10178 non-null  object
#  1   date_x      10178 non-null  datetime64[ns]
#  2   score       10178 non-null  float64
#  3   genre       10093 non-null  object
#  4   overview    10178 non-null  object
#  5   crew        10122 non-null  object
#  6   orig_title  10178 non-null  object
#  7   status      10178 non-null  object
#  8   orig_lang   10178 non-null  object
#  9   budget_x    10178 non-null  float64
#  10  revenue     10178 non-null  float64
#  11  country     10178 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(8)
# memory usage: 954.3+ KB

# %%
# Summary statistics for numerical columns
df.describe()
# Out:
#               score      budget_x       revenue
# count  10178.000000  1.017800e+04  1.017800e+04
# mean      63.497052  6.488238e+07  2.531401e+08
# std       13.537012  5.707565e+07  2.777880e+08
# min        0.000000  1.000000e+00  0.000000e+00
# 25%       59.000000  1.500000e+07  2.858898e+07
# 50%       65.000000  5.000000e+07  1.529349e+08
# 75%       71.000000  1.050000e+08  4.178021e+08
# max      100.000000  4.600000e+08  2.923706e+09

# %%
# 1. Check the shape of the dataset
dataset_shape = df.shape
 # 2. Check data types of each column
data_types = df.dtypes
 # 3. Check for missing values in each column
missing_values = df.isnull().sum()
 # 4. Get summary statistics for numerical columns
summary_statistics = df.describe()
 # 5. Get the number of unique values in categorical columns
unique_values = df.nunique()
 # Compile results
database_info = {
     "Shape (Rows, Columns)": dataset_shape,
    "Data Types": data_types,
    "Missing Values": missing_values,
    "Summary Statistics": summary_statistics,
    "Unique Values Count": unique_values
 }

# %%
from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>3. Data Cleaning</h2>

<p style='font-size:15px; line-height:1.7; text-align:justify;'>
<b>Task:</b> Address missing values, data types, and outliers.  
This step focuses on identifying incomplete records, correcting incorrect data types,
and detecting extreme values that may affect the accuracy of the analysis.
Effective data cleaning ensures that the dataset is consistent, accurate,
and suitable for meaningful insights.
</p>
"""))
# Out:
# <h2 style='color:#2c3e50;'>3. Data Cleaning</h2>
#
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# <b>Task:</b> Address missing values, data types, and outliers.
# This step focuses on identifying incomplete records, correcting incorrect data types,
# and detecting extreme values that may affect the accuracy of the analysis.
# Effective data cleaning ensures that the dataset is consistent, accurate,
# and suitable for meaningful insights.
# </p>

# %%
from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'> Project Questions</h2>

<h3 style='color:#2c3e50;'>1. Which columns contain missing values? How would you handle them?</h3>
<p style='font-size:15px; line-height:1.7; text-align:justify;'>
This question focuses on identifying columns with missing or incomplete data and deciding how to handle 
them. Depending on the column’s importance, missing values may be removed, replaced, or imputed using 
appropriate techniques.
</p>

<h3 style='color:#2c3e50;'>2. Are there any columns where data types need conversion (e.g., date, ratings)? 
Explain your decision.</h3>
<p style='font-size:15px; line-height:1.7; text-align:justify;'>
This involves checking whether certain columns require conversion into more suitable data types. 
For example, converting date fields into <code>datetime</code>, or numerical values stored as strings 
into integers or floats to ensure accurate calculations and proper analysis.
</p>
"""))
# Out:
# <h2 style='color:#2c3e50;'> Project Questions</h2>
#
# <h3 style='color:#2c3e50;'>1. Which columns contain missing values? How would you handle them?</h3>
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# This question focuses on identifying columns with missing or incomplete data and deciding how to handle
# them. Depending on the column’s importance, missing values may be removed, replaced, or imputed using
# appropriate techniques.
# </p>
#
# <h3 style='color:#2c3e50;'>2. Are there any columns where data types need conversion (e.g., date, ratings)?
# Explain your decision.</h3>
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# This involves checking whether certain columns require conversion into more suitable data types.
# For example, converting date fields into <code>datetime</code>, or numerical values stored as strings
# into integers or floats to ensure accurate calculations and proper analysis.
# </p>

# %%
 # Checking for missing values and their counts
df.isnull().sum()
# Out:
# names          0
# date_x         0
# score          0
# genre         85
# overview       0
# crew          56
# orig_title     0
# status         0
# orig_lang      0
# budget_x       0
# revenue        0
# country        0
# dtype: int64

# %%
 #Missing Values: "genre has 85 missing value"
 #Filling Genre with "Not available"
 df['genre'] = df['genre'].fillna('not_available')
 #Missing Values:"crew has 56 missing values"
 #Filling crew with "Not available"
 df['crew'] = df['crew'].fillna('not_available')
 #Checking the missing values again
 df.isnull().sum()
# Out:
# names         0
# date_x        0
# score         0
# genre         0
# overview      0
# crew          0
# orig_title    0
# status        0
# orig_lang     0
# budget_x      0
# revenue       0
# country       0
# dtype: int64

# %%
from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>4. Univariate Analysis: Explore Each Column Individually</h2>

<p style='font-size:15px; line-height:1.7; text-align:justify;'>
<b>Task:</b> Perform univariate analysis on numerical and categorical variables.  
This step helps identify patterns, distributions, and key characteristics of each feature. 
Numerical variables are examined using statistics such as mean, median, variance, and 
visualizations like histograms or boxplots. Categorical variables are analyzed using 
frequency counts and bar charts to understand category distribution.
</p>
"""))
# Out:
# <h2 style='color:#2c3e50;'>4. Univariate Analysis: Explore Each Column Individually</h2>
#
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# <b>Task:</b> Perform univariate analysis on numerical and categorical variables.
# This step helps identify patterns, distributions, and key characteristics of each feature.
# Numerical variables are examined using statistics such as mean, median, variance, and
# visualizations like histograms or boxplots. Categorical variables are analyzed using
# frequency counts and bar charts to understand category distribution.
# </p>

# %%
from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>Project Questions</h2>

<h3 style='color:#2c3e50;'>1. What is the distribution of movie runtimes? Plot a histogram and describe its shape.</h3>
<p style='font-size:15px; line-height:1.7; text-align:justify;'>
This task examines how movie runtimes are spread across the dataset. A histogram helps visualize
the distribution, detect skewness, and identify unusually short or long movies.
</p>

<h3 style='color:#2c3e50;'>2. What are the most common genres in the dataset? Use a bar chart to show their distribution.</h3>
<p style='font-size:15px; line-height:1.7; text-align:justify;'>
This question identifies the most frequently occurring movie genres. A bar chart reveals how 
genres compare in frequency and highlights the dominant categories within the dataset.
</p>
"""))
# Out:
# <h2 style='color:#2c3e50;'>Project Questions</h2>
#
# <h3 style='color:#2c3e50;'>1. What is the distribution of movie runtimes? Plot a histogram and describe its shape.</h3>
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# This task examines how movie runtimes are spread across the dataset. A histogram helps visualize
# the distribution, detect skewness, and identify unusually short or long movies.
# </p>
#
# <h3 style='color:#2c3e50;'>2. What are the most common genres in the dataset? Use a bar chart to show their distribution.</h3>
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# This question identifies the most frequently occurring movie genres. A bar chart reveals how
# genres compare in frequency and highlights the dominant categories within the dataset.
# </p>

# %%
# Analyze the distribution of IMDB ratings (`score`) using a histogram and describe its shape

# Plotting the distribution of IMDB scores
plt.figure(figsize=(12, 4))
sns.histplot(df["score"], kde=True, bins=20, color="green")
plt.title("Distribution of IMDB Scores")
plt.xlabel("IMDB Score")
plt.ylabel("Frequency")
plt.show()


from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>IMDB Score Distribution Analysis</h2>

<p style='font-size:15px; line-height:1.7; text-align:justify;'>
The distribution of IMDB scores shows that it is approximately normal but slightly 
<b>left-skewed</b>, with a noticeable tail toward the lower scores. Most movies have scores 
between <b>50 and 80</b>, forming the dense central region of the distribution. Only a small 
number of films receive extremely low or perfect scores, indicating that such ratings are 
relatively rare in the dataset.
</p>
"""))
# Out:
# <h2 style='color:#2c3e50;'>IMDB Score Distribution Analysis</h2>
#
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# The distribution of IMDB scores shows that it is approximately normal but slightly
# <b>left-skewed</b>, with a noticeable tail toward the lower scores. Most movies have scores
# between <b>50 and 80</b>, forming the dense central region of the distribution. Only a small
# number of films receive extremely low or perfect scores, indicating that such ratings are
# relatively rare in the dataset.
# </p>

# %%
 # What are the most common genres in the dataset? Use a bar chart to show their distribution.

# Group by genre and count the number of movies
gb = df.groupby("genre").agg({"names": "count"})
gb = gb.sort_values(by="names", ascending=False)
gb = gb.head(20)

# Plotting the bar chart
plt.figure(figsize=(12, 4))
sns.barplot(x=gb.index,y=gb["names"],data=gb,hue=gb.index)
plt.title("Most Common Genres")
plt.xlabel("Genre")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.show()

# Print the most common genre
most_common_genre = gb.index[0]
from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>Most Common Genre</h2>

<p style='font-size:15px; line-height:1.7; text-align:justify;'>
The analysis reveals that the most frequently occurring genre in the dataset is 
<b>Drama</b>. This suggests that dramatic storytelling dominates the collection of movies 
represented in the dataset.
</p>
"""))
# Out:
# <h2 style='color:#2c3e50;'>Most Common Genre</h2>
#
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# The analysis reveals that the most frequently occurring genre in the dataset is
# <b>Drama</b>. This suggests that dramatic storytelling dominates the collection of movies
# represented in the dataset.
# </p>

# %%
from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>5. Bivariate Analysis: Explore Relationships Between Two Variables</h2>

<p style='font-size:15px; line-height:1.7; text-align:justify;'>
<b>Task:</b> Use scatter plots, box plots, and correlation analysis.  
This step examines how two variables interact with each other, identifies possible trends, 
detects group differences, and quantifies relationships. Scatter plots help visualize linear 
or nonlinear patterns, box plots reveal distribution differences across categories, and 
correlation analysis measures the strength of associations.
</p>
"""))
# Out:
# <h2 style='color:#2c3e50;'>5. Bivariate Analysis: Explore Relationships Between Two Variables</h2>
#
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# <b>Task:</b> Use scatter plots, box plots, and correlation analysis.
# This step examines how two variables interact with each other, identifies possible trends,
# detects group differences, and quantifies relationships. Scatter plots help visualize linear
# or nonlinear patterns, box plots reveal distribution differences across categories, and
# correlation analysis measures the strength of associations.
# </p>

# %%
from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>Project Questions</h2>

<h3 style='color:#2c3e50;'>1. Is there a relationship between a movie’s runtime and its rating?</h3>
<p style='font-size:15px; line-height:1.7; text-align:justify;'>
Plot a scatter plot to observe any trends between runtime and IMDB rating. This helps identify 
whether longer films tend to be rated higher or lower than shorter ones.
</p>

<h3 style='color:#2c3e50;'>2. How do ratings vary by genre?</h3>
<p style='font-size:15px; line-height:1.7; text-align:justify;'>
Use a boxplot to compare rating distributions across different genres. This allows you to observe 
which genres typically receive higher ratings and which ones show more variability.
</p>

<h3 style='color:#2c3e50;'>3. Is there a correlation between the number of votes, budget, and revenue?</h3>
<p style='font-size:15px; line-height:1.7; text-align:justify;'>
Create scatter plots and calculate the correlation coefficient to determine whether movies with 
higher budgets or more votes tend to generate more revenue. This analysis highlights financial 
and popularity-driven patterns.
</p>
"""))
# Out:
# <h2 style='color:#2c3e50;'>Project Questions</h2>
#
# <h3 style='color:#2c3e50;'>1. Is there a relationship between a movie’s runtime and its rating?</h3>
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# Plot a scatter plot to observe any trends between runtime and IMDB rating. This helps identify
# whether longer films tend to be rated higher or lower than shorter ones.
# </p>
#
# <h3 style='color:#2c3e50;'>2. How do ratings vary by genre?</h3>
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# Use a boxplot to compare rating distributions across different genres. This allows you to observe
# which genres typically receive higher ratings and which ones show more variability.
# </p>
#
# <h3 style='color:#2c3e50;'>3. Is there a correlation between the number of votes, budget, and revenue?</h3>
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# ...

# %%
# Explore the relationship between `budget_x` and `revenue` using a scatter plot.  
# Plotting the Scatter plot
plt.figure(figsize=(12,3))
sns.scatterplot(x="budget_x", y = "revenue",data = df, hue = "budget_x", palette = "viridis")
plt.title("Budget vs Revenue")
plt.xlabel("Budget")
plt.ylabel("Revenue")
plt.show()

from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>Budget vs Revenue Relationship</h2>

<p style='font-size:15px; line-height:1.7; text-align:justify;'>
The analysis shows a strong <b>positive correlation</b> between a movie's budget and revenue. 
Movies with larger budgets tend to generate higher revenues. Most films are clustered around 
<b>mid-range budgets</b> (approximately 80 million), suggesting that this range is common for 
production. The dataset also contains notable outliers, representing both major successes 
(high budget and high revenue) and failures (high budget but low revenue).
</p>
"""))
# Out:
# <h2 style='color:#2c3e50;'>Budget vs Revenue Relationship</h2>
#
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# The analysis shows a strong <b>positive correlation</b> between a movie's budget and revenue.
# Movies with larger budgets tend to generate higher revenues. Most films are clustered around
# <b>mid-range budgets</b> (approximately 80 million), suggesting that this range is common for
# production. The dataset also contains notable outliers, representing both major successes
# (high budget and high revenue) and failures (high budget but low revenue).
# </p>

# %%
# Compare IMDB ratings (`score`) across Country using a boxplot. 

# Boxplot for IMDB score across countries
top_countries = df["country"].value_counts().head(10).index  # Top 10 countries by movie count
plt.figure(figsize=(12, 4))
sns.boxplot(data=df[df["country"].isin(top_countries)], x="country", y="score", hue="country", palette="viridis", legend=False)
plt.title("IMDB Scores by Genre")
plt.xlabel("Genre")
plt.ylabel("IMDB Score")
plt.xticks(rotation=90)
plt.show()

# Description 
from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>IMDB Score Across Countries</h2>

<p style='font-size:15px; line-height:1.7; text-align:justify;'>
The distribution of IMDB ratings varies notably across different countries. 
Some countries show a tighter and more consistent rating pattern, while others exhibit 
a wider range of scores across movies. Additionally, the <b>median rating differs</b> 
from one country to another, revealing insights into regional movie quality and audience preferences.
</p>
"""))
# Out:
# <h2 style='color:#2c3e50;'>IMDB Score Across Countries</h2>
#
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# The distribution of IMDB ratings varies notably across different countries.
# Some countries show a tighter and more consistent rating pattern, while others exhibit
# a wider range of scores across movies. Additionally, the <b>median rating differs</b>
# from one country to another, revealing insights into regional movie quality and audience preferences.
# </p>

# %%
#Is there a correlation between the number of votes a movie received and its rating? Create a scatter plot and calculate the correlation coefficient.
# Create a dataframe to store score, budget and revenue and find it's correlation
df1 = df[["score", "budget_x", "revenue"]]
df1.columns = ["Score","Budget", "Revenue"]
corr = df1.corr()
corr
# Out:
#             Score   Budget   Revenue
# Score    1.000000 -0.23547  0.096533
# Budget  -0.235470  1.00000  0.673830
# Revenue  0.096533  0.67383  1.000000

# %%
#correlation between `budget_x`, 'revenue' and `score`. 
correlation = df[["score","budget_x","revenue"]]
data = correlation.corr()
sns.heatmap(data, annot = True)
plt.show()

from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>Correlation Between Budget, Score, and Revenue</h2>

<p style='font-size:15px; line-height:1.7; text-align:justify;'>
The correlation analysis highlights several key relationships between budget, score, and revenue:
</p>

<ul style='font-size:15px; line-height:1.7;'>
    <li><b>Score and Budget:</b> A weak negative correlation of <b>-0.235</b>, suggesting that higher budgets are slightly associated with lower IMDB scores.</li>
    <li><b>Score and Revenue:</b> A very weak positive correlation of <b>0.097</b>, indicating almost no relationship between a movie's rating and its earning potential.</li>
    <li><b>Budget and Revenue:</b> A moderate positive correlation of <b>0.674</b>, meaning movies with larger budgets tend to generate higher revenues.</li>
</ul>
"""))
# Out:
# <h2 style='color:#2c3e50;'>Correlation Between Budget, Score, and Revenue</h2>
#
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# The correlation analysis highlights several key relationships between budget, score, and revenue:
# </p>
#
# <ul style='font-size:15px; line-height:1.7;'>
#     <li><b>Score and Budget:</b> A weak negative correlation of <b>-0.235</b>, suggesting that higher budgets are slightly associated with lower IMDB scores.</li>
#     <li><b>Score and Revenue:</b> A very weak positive correlation of <b>0.097</b>, indicating almost no relationship between a movie's rating and its earning potential.</li>
#     <li><b>Budget and Revenue:</b> A moderate positive correlation of <b>0.674</b>, meaning movies with larger budgets tend to generate higher revenues.</li>
# </ul>

# %%
# How do ratings vary by genre? Use a boxplot to visualize the differences in ratings across genres.
top_genre = df["genre"].value_counts().head(10).index 
plt.figure(figsize=(12, 4))
sns.boxplot(data=df[df["genre"].isin(top_genre)], x="genre", 
y="score", hue="genre", palette="viridis")
plt.title("IMDB Scores by Genre")
plt.xlabel("Genre")
plt.ylabel("Score")
plt.xticks(rotation=90)
plt.show()

# %%
# Is there a correlation between the number of votes a budget and revenue? 
#Create a scatter plot and calculate the correlation coefficient. What can you conclude?
# Scatter plot
plt.figure(figsize=(8,6))
sns.scatterplot(x=df['budget_x'], y=df['revenue'], alpha=0.5,hue = 
df.index, palette = "viridis")
plt.xlabel('Budget')
plt.ylabel('Revenue')
plt.title('Scatter Plot of Budget vs Revenue')
plt.xscale('log')  # Log scale for better visualization
plt.yscale('log')
plt.grid(True)
plt.show()
 # Compute correlation coefficient
correlation = df['budget_x'].corr(df['revenue'])

print(f'Correlation coefficient between budget and revenue:{correlation:.2f}')
# Out:
# Correlation coefficient between budget and revenue:0.67

# %%
from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>6. Genre-Specific Analysis</h2>

<p style='font-size:15px; line-height:1.7; text-align:justify;'>
<b>Task:</b> Delve deeper into the genre of movies.  
This analysis explores genre-based patterns such as rating differences, financial trends, 
audience preferences, and overall performance. Understanding genre-specific behavior helps 
identify which genres perform better and why.
</p>
"""))
# Out:
# <h2 style='color:#2c3e50;'>6. Genre-Specific Analysis</h2>
#
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# <b>Task:</b> Delve deeper into the genre of movies.
# This analysis explores genre-based patterns such as rating differences, financial trends,
# audience preferences, and overall performance. Understanding genre-specific behavior helps
# identify which genres perform better and why.
# </p>

# %%
from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>Questions</h2>

<h3 style='color:#2c3e50;'>1. Which genre has the highest average rating?</h3>
<p style='font-size:15px; line-height:1.7; text-align:justify;'>
Calculate the average rating for each genre and visualize the results in a plot.
This helps identify the genres that consistently receive higher ratings from audiences.
</p>

<h3 style='color:#2c3e50;'>2. How does the popularity of genres vary over time?</h3>
<p style='font-size:15px; line-height:1.7; text-align:justify;'>
Plot the number of movies released per genre each year to explore changes in popularity.
This reveals long-term trends and shifts in the types of movies produced over time.
</p>
"""))
# Out:
# <h2 style='color:#2c3e50;'>Questions</h2>
#
# <h3 style='color:#2c3e50;'>1. Which genre has the highest average rating?</h3>
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# Calculate the average rating for each genre and visualize the results in a plot.
# This helps identify the genres that consistently receive higher ratings from audiences.
# </p>
#
# <h3 style='color:#2c3e50;'>2. How does the popularity of genres vary over time?</h3>
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# Plot the number of movies released per genre each year to explore changes in popularity.
# This reveals long-term trends and shifts in the types of movies produced over time.
# </p>

# %%
# Which genre has the highest average rating? Calculate the average rating for each genre and plot the results.

# Calculate the average rating for each genre
avg_rating_by_genre= df.groupby("genre")["score"].mean().sort_values(ascending=False)
avg_rating_by_genre = avg_rating_by_genre.head(10)
print("\nAverage Ratings by Genre:")
print(avg_rating_by_genre)
# Out:
# Average Ratings by Genre:
# genre
# Fantasy, Drama, Crime                                 85.000000
# Adventure, Animation, Comedy, Fantasy, Mystery        85.000000
# Romance, Animation, Drama                             85.000000
# Animation, Comedy, Romance                            84.666667
# Family, Animation, Drama                              83.000000
# Animation, Action, Comedy, Mystery, Crime, Fantasy    83.000000
# Animation, Action, Science Fiction, Drama             83.000000
# Animation, Action, Adventure, Fantasy, Thriller       83.000000
# Animation, Family, Fantasy, Adventure, Comedy         83.000000
# Adventure, Fantasy, Animation                         83.000000
# Name: score, dtype: float64

# %%
# Plot the graph of average score across genres
plt.figure(figsize=(12, 4))
sns.barplot(x=avg_rating_by_genre.index, y=avg_rating_by_genre.values, hue=avg_rating_by_genre.index, palette='viridis', legend=False)
plt.title("Average IMDB Ratings by Genre")
plt.xlabel("Genre")
plt.ylabel("Average Rating")
plt.xticks(rotation=90)
plt.show()

from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>Description</h2>

<p style='font-size:15px; line-height:1.7; text-align:justify;'>
The average rating for each genre indicates several high-performing categories:
</p>

<ul style='font-size:15px; line-height:1.7;'>
    <li><b>Fantasy, Drama, Crime</b> show some of the highest scores.</li>
    <li><b>Adventure, Animation, Comedy, Fantasy, Mystery</b> also appear strong.</li>
    <li><b>Romance, Animation, Drama</b> consistently achieve high ratings.</li>
</ul>
"""))
# Out:
# <h2 style='color:#2c3e50;'>Description</h2>
#
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# The average rating for each genre indicates several high-performing categories:
# </p>
#
# <ul style='font-size:15px; line-height:1.7;'>
#     <li><b>Fantasy, Drama, Crime</b> show some of the highest scores.</li>
#     <li><b>Adventure, Animation, Comedy, Fantasy, Mystery</b> also appear strong.</li>
#     <li><b>Romance, Animation, Drama</b> consistently achieve high ratings.</li>
# </ul>

# %%
# How does the popularity of genres vary over time? Plot the number of movies released per genre each year.

# Convert 'date_x' to datetime format if it's not already
df['date_x'] = pd.to_datetime(df['date_x'], errors='coerce')

# Extract the year from the 'date_x' column
df['year'] = df['date_x'].dt.year

# Check if the 'year' column is created correctly
print(df[['date_x', 'year']].head())
# Out:
#       date_x  year
# 0 2023-03-02  2023
# 1 2022-12-15  2022
# 2 2023-04-05  2023
# 3 2023-01-05  2023
# 4 2023-03-17  2023

# %%
# Group by 'genre' and 'year', then count movies
movies_per_genre = df.groupby(['year', 'genre']).size().reset_index(name='movie_count')
top_genres = movies_per_genre.groupby('genre')['movie_count'].sum().nlargest(10).index

# Filter the movies data to include only these top genres
filtered_movies = movies_per_genre[movies_per_genre['genre'].isin(top_genres)]

# %%
# Plotting Line 
plt.figure(figsize=(12,4))
sns.lineplot(data=filtered_movies, x='year', y='movie_count', hue='genre', marker='o')
plt.title("Number of Movies Released Per Genre Each Year")
plt.xlabel("Year")
plt.ylabel("Number of Movies Released")
plt.xticks(rotation=45)
plt.show()

# %%
# Compare budgets and revenues for specific genres.

# Filter data for specific genres
selected_genres = ['Action', 'Comedy', 'Drama']
df_selected_genres = df[df['genre'].isin(selected_genres)]

# Check the first few rows of the filtered data
print(df_selected_genres[['genre', 'budget_x', 'revenue']].head())
# Out:
#      genre    budget_x      revenue
# 4   Action  77000000.0  340941958.6
# 22   Drama  25000000.0  622313635.0
# 42  Action   1000000.0   22790427.2
# 44   Drama   3000000.0   36752010.0
# 54  Comedy  51880004.0    9263009.0

# %%
# Group by 'genre' and calculate the average budget and revenue
genre_comparison = df_selected_genres.groupby('genre')[['budget_x', 'revenue']].mean()

# Check the result
print(genre_comparison)
# Out:
#             budget_x       revenue
# genre
# Action  4.698863e+07  1.962566e+08
# Comedy  5.767277e+07  2.052982e+08
# Drama   6.068989e+07  2.495831e+08

# %%
# Plot the comparison of average budget and revenue per genre
genre_comparison.plot(kind='bar', figsize=(12,4 ))
plt.title("Average Budget and Revenue Comparison by Genre")
plt.xlabel("Genre")
plt.ylabel("Amount (in millions)")
plt.xticks(rotation=0)
plt.show()

from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>Description</h2>

<p style='font-size:15px; line-height:1.7; text-align:justify;'>
The analysis of average budget and revenue by genre reveals notable differences:
</p>

<ul style='font-size:15px; line-height:1.7;'>
    <li>The <b>Drama</b> genre generally requires a <b>higher budget</b> to produce.</li>
    <li><b>Action</b> movies typically require <b>less budget</b> compared to Comedy and Drama.</li>
</ul>
"""))
# Out:
# <h2 style='color:#2c3e50;'>Description</h2>
#
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# The analysis of average budget and revenue by genre reveals notable differences:
# </p>
#
# <ul style='font-size:15px; line-height:1.7;'>
#     <li>The <b>Drama</b> genre generally requires a <b>higher budget</b> to produce.</li>
#     <li><b>Action</b> movies typically require <b>less budget</b> compared to Comedy and Drama.</li>
# </ul>

# %%
from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>7. Year and Trend Analysis</h2>

<p style='font-size:15px; line-height:1.7; text-align:justify;'>
<b>Task:</b> Analyze trends over time.  
This involves studying how key movie characteristics evolve year by year, including 
ratings, genre popularity, production budgets, and revenues. Understanding these trends 
helps identify industry patterns and emerging shifts in filmmaking.
</p>
"""))
# Out:
# <h2 style='color:#2c3e50;'>7. Year and Trend Analysis</h2>
#
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# <b>Task:</b> Analyze trends over time.
# This involves studying how key movie characteristics evolve year by year, including
# ratings, genre popularity, production budgets, and revenues. Understanding these trends
# helps identify industry patterns and emerging shifts in filmmaking.
# </p>

# %%
from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>Questions</h2>

<h3 style='color:#2c3e50;'>1. How has the average movie rating changed over the years?</h3>
<p style='font-size:15px; line-height:1.7; text-align:justify;'>
Plot the average rating for each year to analyze how audience perception and movie quality 
have evolved over time. This helps identify long-term rating trends.
</p>

<h3 style='color:#2c3e50;'>2. Which years had the highest and lowest number of movie releases?</h3>
<p style='font-size:15px; line-height:1.7; text-align:justify;'>
Plot the count of movies released every year to observe production patterns. This highlights 
periods of high cinematic activity as well as years with fewer releases.
</p>
"""))
# Out:
# <h2 style='color:#2c3e50;'>Questions</h2>
#
# <h3 style='color:#2c3e50;'>1. How has the average movie rating changed over the years?</h3>
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# Plot the average rating for each year to analyze how audience perception and movie quality
# have evolved over time. This helps identify long-term rating trends.
# </p>
#
# <h3 style='color:#2c3e50;'>2. Which years had the highest and lowest number of movie releases?</h3>
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# Plot the count of movies released every year to observe production patterns. This highlights
# periods of high cinematic activity as well as years with fewer releases.
# </p>

# %%
# How has the average movie rating changed over the years? Plot the average rating for each year.  

# Group by 'year' and calculate the average rating ('score') for each year
average_rating_per_year = df.groupby('year')['score'].mean().reset_index()

# Showing line plot for average movie changed over years
plt.figure(figsize=(12,3))
sns.lineplot(data=average_rating_per_year, x='year', y='score', marker='o', color='b')
plt.title("Average Movie Rating Over the Years")
plt.xlabel("Year")
plt.ylabel("Average Rating")
plt.xticks(rotation=45)
plt.show()

from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>Average Movie Rating Over the Years</h2>

<p style='font-size:15px; line-height:1.7; text-align:justify;'>
The trend in average movie ratings from 1980 to 2020 shows a period of consistent movie quality.  
However, after 2020, there is a noticeable decline in ratings, which may be attributed to evolving 
audience expectations or broader changes in the movie industry.
</p>
"""))
# Out:
# <h2 style='color:#2c3e50;'>Average Movie Rating Over the Years</h2>
#
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# The trend in average movie ratings from 1980 to 2020 shows a period of consistent movie quality.
# However, after 2020, there is a noticeable decline in ratings, which may be attributed to evolving
# audience expectations or broader changes in the movie industry.
# </p>

# %%
# Which years had the highest and lowest number of movie releases? Plot the number of movies released each year

# Group by 'year' and count the number of movies released each year
gb4 = df.groupby('year').agg({'names': 'count'})

# Plot the number of movies released each year using a bar plot
plt.figure(figsize=(14,4))
sns.barplot(x=gb4.index, y=gb4['names'], hue=gb4.index, palette='viridis')
plt.ylabel('Count of Movies Released')
plt.xlabel('Year')
plt.title('Movies Released Each Year')
plt.xticks(rotation=90, fontsize=7)
plt.show()

# Find the year with the highest number of movie releases
highest_releases_year = gb4['names'].idxmax()  # This gives the year with the highest releases
print(f"Year with the highest movie releases: {highest_releases_year}")

# Find the year with the lowest number of movie releases
lowest_releases_year = gb4['names'].idxmin()  # This gives the year with the lowest releases
print(f"Year with the lowest movie releases: {lowest_releases_year}")
# Out:
# Year with the highest movie releases: 2022
# Year with the lowest movie releases: 1903

# %%
# Do certain years show a higher average budget? Analyze the average budget by year and observe any trends.

# Group by 'year' and calculate the average budget for each year
average_budget_per_year = df.groupby('year')['budget_x'].mean()

# Plot the average budget per year using a line plot
plt.figure(figsize=(12, 6))
sns.lineplot(x=average_budget_per_year.index, y=average_budget_per_year.values, marker='o', color='y')
plt.title("Average Movie Budget Over the Years")
plt.xlabel("Year")
plt.ylabel("Average Budget")
plt.xticks(rotation=45)
plt.show()

# %%
from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>8. Multivariate Analysis: Analyze Multiple Variables Together</h2>

<p style='font-size:15px; line-height:1.7; text-align:justify;'>
<b>Task:</b> Combine insights from multiple columns to explore complex relationships.  
This analysis looks at how various factors—such as budget, revenue, ratings, genres, and 
release years—interact with each other. It helps uncover deeper patterns that cannot be 
observed through single-variable or pair-wise analysis alone.
</p>
"""))
# Out:
# <h2 style='color:#2c3e50;'>8. Multivariate Analysis: Analyze Multiple Variables Together</h2>
#
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# <b>Task:</b> Combine insights from multiple columns to explore complex relationships.
# This analysis looks at how various factors—such as budget, revenue, ratings, genres, and
# release years—interact with each other. It helps uncover deeper patterns that cannot be
# observed through single-variable or pair-wise analysis alone.
# </p>

# %%
from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>Questions</h2>

<h3 style='color:#2c3e50;'>1. Which genres are most popular in each decade?</h3>
<p style='font-size:15px; line-height:1.7; text-align:justify;'>
Create a bar plot showing the most common genres for each decade to reveal long-term patterns 
and shifts in genre popularity over time.
</p>

<h3 style='color:#2c3e50;'>2. Plot a heatmap or pairplot to examine relationships between budget, revenue, and scores.</h3>
<p style='font-size:15px; line-height:1.7; text-align:justify;'>
Visualize the interactions between numerical variables using heatmaps or pairplots. These 
visualizations help highlight correlations and uncover complex relationships between 
budget, revenue, and IMDB scores.
</p>

<h3 style='color:#2c3e50;'>3. Are there specific genres or release years with higher-rated movies?</h3>
<p style='font-size:15px; line-height:1.7; text-align:justify;'>
Group the dataset by genre and year to analyze average ratings. This helps identify which 
genres or time periods consistently produce higher-rated films.
</p>
"""))
# Out:
# <h2 style='color:#2c3e50;'>Questions</h2>
#
# <h3 style='color:#2c3e50;'>1. Which genres are most popular in each decade?</h3>
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# Create a bar plot showing the most common genres for each decade to reveal long-term patterns
# and shifts in genre popularity over time.
# </p>
#
# <h3 style='color:#2c3e50;'>2. Plot a heatmap or pairplot to examine relationships between budget, revenue, and scores.</h3>
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# Visualize the interactions between numerical variables using heatmaps or pairplots. These
# visualizations help highlight correlations and uncover complex relationships between
# budget, revenue, and IMDB scores.
# </p>
#
# <h3 style='color:#2c3e50;'>3. Are there specific genres or release years with higher-rated movies?</h3>
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# ...

# %%
# Which genres are most popular in each decade? Create a bar plot showing the most frequent genres by decade.

# Extract the decade from the 'year' column
df['decade'] = (df['year'] // 10) * 10  # Dividing year by 10 and multiplying by 10 to get the start of the decade

# Plot the number of movies released each decade
gb = df.groupby('decade').agg({'genre':'count'})
plt.figure(figsize = (12, 4))
sns.barplot(x = gb.index, y = gb['genre'], data = gb, hue = gb.index, palette = 'viridis')
plt.ylabel('Count of Movies Released')
plt.xlabel('Year')
plt.title('Movies Released each Decade')
plt.xticks(rotation = 90, fontsize = 7)
plt.show()

from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>Description</h2>

<p style='font-size:15px; line-height:1.7; text-align:justify;'>
The analysis of movies released per decade shows that:
</p>

<ul style='font-size:15px; line-height:1.7;'>
    <li>The <b>2010</b> experienced the highest number of movie releases, reflecting a peak in production and audience engagement.</li>
</ul>
"""))
# Out:
# <h2 style='color:#2c3e50;'>Description</h2>
#
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# The analysis of movies released per decade shows that:
# </p>
#
# <ul style='font-size:15px; line-height:1.7;'>
#     <li>The <b>2010</b> experienced the highest number of movie releases, reflecting a peak in production and audience engagement.</li>
# </ul>

# %%
# Analyze the influence of `budget_x`, `genre`, and `country` on revenues using a heatmap.

# Select the relevant columns and drop any missing values
df_corr = df[['budget_x', 'genre', 'country', 'revenue']].dropna()

# Convert categorical columns into numeric values
df_corr['genre'] = pd.factorize(df_corr['genre'])[0]
df_corr['country'] = pd.factorize(df_corr['country'])[0]

# Calculate the correlation between the variables
corr_matrix = df_corr.corr()

print(corr_matrix)
# Out:
#           budget_x     genre   country   revenue
# budget_x  1.000000 -0.013033  0.170086  0.673830
# genre    -0.013033  1.000000 -0.024469 -0.012112
# country   0.170086 -0.024469  1.000000  0.145555
# revenue   0.673830 -0.012112  0.145555  1.000000

# %%
# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap: Budget, Genre, Country, and Revenue")
plt.show()

from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>Correlation Heatmap Insights</h2>

<p style='font-size:15px; line-height:1.7; text-align:justify;'>
The correlation heatmap highlights several relationships among key variables:
</p>

<ul style='font-size:15px; line-height:1.7;'>
    <li><b>Budget and revenue</b> show a strong positive correlation (<b>0.67</b>), indicating that higher-budget films generally earn more revenue.</li>
    <li><b>Genre</b> and <b>country</b> exhibit very weak correlations with other variables, suggesting they do not strongly impact budget or revenue.</li>
    <li><b>Country</b> has a weak positive correlation with revenue, implying that movies from certain countries may achieve slightly higher revenue.</li>
</ul>
"""))
# Out:
# <h2 style='color:#2c3e50;'>Correlation Heatmap Insights</h2>
#
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# The correlation heatmap highlights several relationships among key variables:
# </p>
#
# <ul style='font-size:15px; line-height:1.7;'>
#     <li><b>Budget and revenue</b> show a strong positive correlation (<b>0.67</b>), indicating that higher-budget films generally earn more revenue.</li>
#     <li><b>Genre</b> and <b>country</b> exhibit very weak correlations with other variables, suggesting they do not strongly impact budget or revenue.</li>
#     <li><b>Country</b> has a weak positive correlation with revenue, implying that movies from certain countries may achieve slightly higher revenue.</li>
# </ul>

# %%
# Which countries produce the highest-rated movies on average? 

# Group by 'country' and calculate the average rating ('score') for each country
average_rating_by_country = df.groupby('country')['score'].mean().sort_values(ascending=False).reset_index()

# Display the top 10 countries with the highest average ratings
top_countries = average_rating_by_country.head(10)
print("Top 10 Countries with Highest Average Movie Ratings:")
print(top_countries)
# Out:
# Top 10 Countries with Highest Average Movie Ratings:
#   country      score
# 0      SU  79.800000
# 1      PR  76.000000
# 2      XC  76.000000
# 3      CZ  72.500000
# 4      DO  72.000000
# 5      PY  71.000000
# 6      MU  70.000000
# 7      MX  69.771429
# 8      GT  68.000000
# 9      DK  67.333333

# %%
# Plot the results using a barplot
plt.figure(figsize=(12, 6))
sns.barplot(data=top_countries, x='country', y='score',hue=top_countries.index, palette='viridis')
plt.title("Top 10 Countries with Highest Average Movie Ratings")
plt.xlabel("Country")
plt.ylabel("Average Rating")
plt.xticks(rotation=90) 
plt.show()

from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>Description</h2>

<p style='font-size:15px; line-height:1.7; text-align:justify;'>
The analysis of highest average movie ratings reveals that:
</p>

<ul style='font-size:15px; line-height:1.7;'>
    <li><b>SU</b> has the highest average movie ratings compared to other countries or regions.</li>
</ul>
"""))
# Out:
# <h2 style='color:#2c3e50;'>Description</h2>
#
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# The analysis of highest average movie ratings reveals that:
# </p>
#
# <ul style='font-size:15px; line-height:1.7;'>
#     <li><b>SU</b> has the highest average movie ratings compared to other countries or regions.</li>
# </ul>

# %%
# Does the original language (`orig_lang`) correlate with ratings?  

# Group by 'orig_lang' and calculate the average rating for each language
avg_rating_by_lang = df.groupby('orig_lang')['score'].mean().sort_values(ascending=False).reset_index()

top= avg_rating_by_lang.head(20)

# Display the results
print("Average Ratings by Original Language:")
print(top)
# Out:
# Average Ratings by Original Language:
#                                orig_lang      score
# 0                                  Irish  76.000000
# 1                                  Czech  75.500000
# 2                                Kannada  75.500000
# 3                               Galician  75.000000
# 4                               Dzongkha  74.000000
# 5                               Gujarati  73.000000
# 6                               Romanian  72.500000
# 7                              Ukrainian  71.500000
# 8                                 Arabic  71.500000
# 9                                  Latin  71.000000
# 10                    Catalan, Valencian  71.000000
# 11                                Danish  69.304348
# 12                               Persian  68.200000
# 13                                 Hindi  67.653846
# 14                            Indonesian  67.636364
# 15   Bokmål, Norwegian, Norwegian Bokmål  67.000000
# ...

# %%
# Plot the results using a barplot
plt.figure(figsize=(12,4))
sns.barplot(data=top, x='orig_lang', y='score', hue = top.index, palette='viridis')
plt.title("Average Movie Ratings by Original Language")
plt.xlabel("Original Language")
plt.ylabel("Average Rating")
plt.xticks(rotation=90)
plt.show()

# %%
df["status"]
# Out:
# 0         Released
# 1         Released
# 2         Released
# 3         Released
# 4         Released
#            ...
# 10173     Released
# 10174     Released
# 10175     Released
# 10176     Released
# 10177     Released
# Name: status, Length: 10178, dtype: object

# %%
# How does `status` (e.g., released, post-production) influence revenues?  

# Filter out movies with invalid revenue values (e.g., 0 or NaN)
df_filtered_revenue = df[df['revenue'] > 0]  # Filter out rows with zero revenue

# Group by 'status' and calculate the average revenue for each status
avg_revenue_by_status = df_filtered_revenue.groupby('status')['revenue'].mean().reset_index()

# Plot the average revenue by status
plt.figure(figsize=(12, 6))
sns.barplot(data=avg_revenue_by_status, x='status', y='revenue',hue=avg_revenue_by_status.index, palette='viridis')
plt.title("Average Revenue by Movie Status")
plt.xlabel("Status")
plt.ylabel("Average Revenue (in millions)")
plt.xticks(rotation=45)
plt.show()

from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>Description</h2>

<p style='font-size:15px; line-height:1.7; text-align:justify;'>
The average revenue comparison across different movie statuses shows that:
</p>

<ul style='font-size:15px; line-height:1.7;'>
    <li>The <b>Released</b> status category has the <b>highest average revenue</b>, indicating stronger overall financial performance.</li>
</ul>
"""))
# Out:
# <h2 style='color:#2c3e50;'>Description</h2>
#
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# The average revenue comparison across different movie statuses shows that:
# </p>
#
# <ul style='font-size:15px; line-height:1.7;'>
#     <li>The <b>Released</b> status category has the <b>highest average revenue</b>, indicating stronger overall financial performance.</li>
# </ul>

# %%
from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>9. Insights and Summary</h2>

<p style='font-size:15px; line-height:1.7; text-align:justify;'>
<b>Task:</b> Summarize key findings.  
This section provides an overview of the most important insights obtained from the analysis. 
It highlights key patterns, major trends, correlations, genre observations, and year-wise changes, 
offering a comprehensive conclusion of the project.
</p>
"""))
# Out:
# <h2 style='color:#2c3e50;'>9. Insights and Summary</h2>
#
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# <b>Task:</b> Summarize key findings.
# This section provides an overview of the most important insights obtained from the analysis.
# It highlights key patterns, major trends, correlations, genre observations, and year-wise changes,
# offering a comprehensive conclusion of the project.
# </p>

# %%
from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>Questions</h2>

<h3 style='color:#2c3e50;'>1. Based on your analysis, what are three major insights you learned about movie trends, popular genres, or movie ratings?</h3>
<p style='font-size:15px; line-height:1.7; text-align:justify;'>
Summarize the most meaningful takeaways from the entire analysis, such as long-term trends,
high-performing genres, rating patterns, or relationships between budget, revenue, and audience perception.
</p>

<h3 style='color:#2c3e50;'>2. What additional questions could be explored with this dataset, or what other data would be helpful to gain a deeper understanding?</h3>
<p style='font-size:15px; line-height:1.7; text-align:justify;'>
Suggest further research directions or additional data that could offer deeper insights—such as audience demographics,
streaming platform performance, marketing spend, critic scores, or international box office data.
</p>
"""))
# Out:
# <h2 style='color:#2c3e50;'>Questions</h2>
#
# <h3 style='color:#2c3e50;'>1. Based on your analysis, what are three major insights you learned about movie trends, popular genres, or movie ratings?</h3>
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# Summarize the most meaningful takeaways from the entire analysis, such as long-term trends,
# high-performing genres, rating patterns, or relationships between budget, revenue, and audience perception.
# </p>
#
# <h3 style='color:#2c3e50;'>2. What additional questions could be explored with this dataset, or what other data would be helpful to gain a deeper understanding?</h3>
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# Suggest further research directions or additional data that could offer deeper insights—such as audience demographics,
# streaming platform performance, marketing spend, critic scores, or international box office data.
# </p>

# %%
from IPython.display import display, HTML

display(HTML("""
<h2 style='color:#2c3e50;'>Key Insights</h2>

<h3 style='color:#2c3e50;'>1. Popular Genres and Their Performance</h3>
<p style='font-size:15px; line-height:1.7; text-align:justify;'>
Genres such as <b>Drama, Fantasy, Crime,</b> and <b>Animation</b> consistently perform well in
terms of ratings and popularity. Drama appears most frequently in the dataset and maintains
high ratings, making it one of the most widely produced and well-received genres.
 In contrast, Action films often have lower production costs but can still generate significant box-office returns,
 showing that action-based content might be more accessible or widely popular despite its lower production costs.
</p>

<h3 style='color:#2c3e50;'>2. Budget Strongly Influences Revenue</h3>
<p style='font-size:15px; line-height:1.7; text-align:justify;'>
There is a moderate to strong positive correlation between <b>budget</b> and <b>revenue</b>, 
suggesting that movies with higher investment tend to generate higher returns. However, movie 
ratings show almost no correlation with revenue, implying that critical or audience approval 
does not guarantee financial success. There is a strong positive correlation (0.67) between budget and revenue, 
indicating that movies with higher budgets tend to generate more revenue. 
This suggests that investing more in movie production is likely to lead to higher financial returns.
</p>

<h3 style='color:#2c3e50;'>3. Ratings Have Changed Over Time</h3>
<p style='font-size:15px; line-height:1.7; text-align:justify;'>
Movie ratings remained fairly consistent from 1980 to 2020 but declined afterward, possibly due 
to changing audience expectations, the rise of streaming platforms, or global events that impacted 
production quality and viewing patterns. This highlights evolving trends in audience behavior and 
industry dynamics.
From 1980 to 2020, the average IMDB ratings have remained relatively consistent, showing that movie quality,
as measured by user ratings, has not drastically changed over time. However, there has been a slight decline after 2020, 
which could be attributed to shifting audience expectations, 
a decrease in movie-going experiences due to external factors (such as the pandemic), 
or a change in the types of content being produced.
</p>
"""))
# Out:
# <h2 style='color:#2c3e50;'>Key Insights</h2>
#
# <h3 style='color:#2c3e50;'>1. Popular Genres and Their Performance</h3>
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# Genres such as <b>Drama, Fantasy, Crime,</b> and <b>Animation</b> consistently perform well in
# terms of ratings and popularity. Drama appears most frequently in the dataset and maintains
# high ratings, making it one of the most widely produced and well-received genres.
#  In contrast, Action films often have lower production costs but can still generate significant box-office returns,
#  showing that action-based content might be more accessible or widely popular despite its lower production costs.
# </p>
#
# <h3 style='color:#2c3e50;'>2. Budget Strongly Influences Revenue</h3>
# <p style='font-size:15px; line-height:1.7; text-align:justify;'>
# There is a moderate to strong positive correlation between <b>budget</b> and <b>revenue</b>,
# ...
